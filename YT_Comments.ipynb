# %% [markdown]
# # **PULL COMMENTS FROM YOUTUBE VIDEO**

# %%
# Importing necessary modules from the Google API client library for YouTube Data API
import googleapiclient.discovery
import googleapiclient.errors

# Setting up the parameters for the YouTube Data API
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB-2SJlE-m29A8e9udk-TeWeYzSwEaVmO4"

# Building the YouTube API client
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# Creating a request to retrieve comment threads for a specific video
request = youtube.commentThreads().list(
    part="snippet",
    videoId="45mnmy2JUl0",
    maxResults=100
)

# Executing the request and storing the response
response = request.execute()

# Iterating through the items in the response and printing the text of each top-level comment
for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Или минин научил или спиздил
# This video is gold ngl
# Is this used in website ? I have yet to learn website development so I have no idea what this is but I have saved it
# this is horrible UX. closed panels have no labels. there&#39;s a reason accordions are vertical.
# Is there any library for reactjsfor these type of carousel ?
# better is width: fill-available;
# This is standard not stunning
# Can you do something similar to this with a tags if I wanted to have an image description but when you click on the tabs it brings you to a new page?
# у владилена минина спиздил идею 😀
# So this is where Codepens go to die. Bet.
# Emeğine sağlık ❤<br>Eğer bu animasyonda solda ok ve sağda ok olan bir slider olsaymış ve kullanıcı oklara tıkladığın ortaya gelen resim otomatik açılıp sola giden veya sağa giden resim otomatik kapansaymış efsane bir animasyon slider olurmuş
# ...

# %% [markdown]
# # **SAVE DATA AS PANDAS**

# %%
# Importing necessary modules from the Google API client library for YouTube Data API
import googleapiclient.discovery
import pandas as pd

# Setting up the parameters for the YouTube Data API
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyB-2SJlE-m29A8e9udk-TeWeYzSwEaVmO4"

# Building the YouTube API client
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# Creating a request to retrieve comment threads for a specific video
request = youtube.commentThreads().list(
    part="snippet",
    videoId="45mnmy2JUl0",
    maxResults=100
)

# Executing the request and storing the response
response = request.execute()

# Creating an empty list to store comment data
comments = []

# Iterating through the items in the response and extracting relevant comment information
for item in response['items']:
    # Extracting information from the snippet of the top-level comment
    comment = item['snippet']['topLevelComment']['snippet']

    # Appending comment information to the list as a list of values
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

# Creating a Pandas DataFrame from the list of comments
df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

# Displaying the first 20 rows of the DataFrame
df.head(20)
# Out:
#                   author          published_at            updated_at  \
# 0             @olegs4418  2023-12-17T01:39:41Z  2023-12-17T01:39:41Z
# 1                 @ndwho  2023-12-16T23:42:38Z  2023-12-16T23:42:38Z
# 2         @FEELING_ECCHI  2023-12-16T20:58:42Z  2023-12-16T20:58:42Z
# 3              @ninibupu  2023-12-16T19:42:01Z  2023-12-16T19:42:01Z
# 4     @shazamshakeel6577  2023-12-15T07:02:01Z  2023-12-15T07:02:01Z
# 5             @grischpel  2023-12-15T04:04:36Z  2023-12-15T04:04:36Z
# 6             @TheKryuko  2023-12-14T12:06:20Z  2023-12-14T12:06:20Z
# 7            @BillyBober  2023-12-13T21:35:25Z  2023-12-13T21:35:25Z
# 8                @hexvel  2023-12-13T21:34:03Z  2023-12-13T21:34:03Z
# 9               @seshdbn  2023-12-12T17:35:23Z  2023-12-12T17:35:23Z
# 10       @ahmetsoner9106  2023-12-11T20:22:42Z  2023-12-11T20:22:42Z
# 11              @Noel_VI  2023-12-11T18:53:04Z  2023-12-11T18:53:04Z
# 12            @DerTheoGD  2023-12-09T22:00:48Z  2023-12-09T22:00:48Z
# ...

# %% [markdown]
# # **SORT COMMENTS ON BASIS OF LIKES**

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                   author          published_at            updated_at  \
# 20            @HGGdragon  2023-10-30T00:16:22Z  2023-10-30T00:16:22Z
# 24              @erpetek  2023-10-06T06:16:31Z  2023-10-06T06:16:31Z
# 26         @Martin-ru3yn  2023-08-01T18:18:23Z  2023-08-01T18:18:48Z
# 28   @pushkalkishore1184  2023-06-19T16:40:40Z  2023-06-19T16:40:40Z
# 23    @jheanbrizadao2429  2023-10-22T20:32:59Z  2023-10-22T20:32:59Z
# 11              @Noel_VI  2023-12-11T18:53:04Z  2023-12-11T18:53:04Z
# 12            @DerTheoGD  2023-12-09T22:00:48Z  2023-12-09T22:00:48Z
# 3              @ninibupu  2023-12-16T19:42:01Z  2023-12-16T19:42:01Z
# 18  @robertzohrabyan3316  2023-11-10T16:55:53Z  2023-11-10T16:55:53Z
# 0             @olegs4418  2023-12-17T01:39:41Z  2023-12-17T01:39:41Z
#
#     like_count                                               text
# 20          21  Really clever use of the radio elements! nicel...
# 24          21  smart usage of radio buttons, i thought you&#3...
# ...
